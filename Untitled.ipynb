# %%
import numpy as np
import pandas as pd
from scipy.spatial import KDTree
import spotipy
import pickle

# %%
# df = pd.read_csv('./data/SpotifyAudioFeaturesApril2019.csv')
df = pd.read_csv('./data/merged_data.csv')

# %%
df.head()
# Out:
#   artist_name                track_id  \
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1          YG  1tHDG53xJNGsItRA3vfVgs
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
#
#                                        track_name  acousticness  danceability  \
# 0  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820         0.743
# 1                    BAND DRUM (feat. A$AP Rocky)      0.024400         0.846
# 2                                   Radio Silence      0.025000         0.603
# 3                                         Lactose      0.029400         0.800
# 4                             Same - Original mix      0.000035         0.783
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       238373   0.339             0.000    1    0.0812    -7.678     1
# 1       214800   0.557             0.000    8    0.2860    -7.259     1
# 2       138913   0.723             0.000    9    0.0824    -5.890     0
# 3       125381   0.579             0.912    5    0.0994   -12.118     0
# 4       124016   0.792             0.878    7    0.0332   -10.277     1
#
#    speechiness    tempo  time_signature  valence  popularity
# 0       0.4090  203.927               4    0.118          15
# 1       0.4570  159.009               4    0.371           0
# 2       0.0454  114.966               4    0.382          56
# 3       0.0701  123.003               4    0.641           0
# 4       0.0661  120.047               4    0.928           0

# %%
df['track_id'][2]
# Out:
# '6Wosx2euFPMT14UXiWudMy'

# %%
model = KDTree(df.drop(['artist_name', 'track_id', 'track_name', 'duration_ms', 'popularity'], axis = 1))

# %%
result = model.query(df[df['track_id'] == '6Wosx2euFPMT14UXiWudMy'].drop(['artist_name', 'track_id', 'track_name', 'duration_ms', 'popularity'], axis = 1), k = 11)

# %%
df[df['track_id'] == '2RM4jf1Xa9zPgMGRDiht8O']
# Out:
#        artist_name                track_id  \
# 0               YG  2RM4jf1Xa9zPgMGRDiht8O
# 130663          YG  2RM4jf1Xa9zPgMGRDiht8O
#
#                                             track_name  acousticness  \
# 0       Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj       0.00582
# 130663  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj       0.00582
#
#         danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 0              0.743       238373   0.339               0.0    1    0.0812
# 130663         0.743       238373   0.339               0.0    1    0.0812
#
#         loudness  mode  speechiness    tempo  time_signature  valence  \
# 0         -7.678     1        0.409  203.927               4    0.118
# 130663    -7.678     1        0.409  203.927               4    0.118
#
#         popularity
# 0               15
# 130663          44

# %%
result[1][0][1:11]
# Out:
# array([121994, 130665, 218586,  78433, 190258,  15200,  38319, 159954,
#         68441, 182832])

# %%
result = model.query([[.02, .5, .5, .1, 1, .1, -5, 1, .5, 200, 4, .5]], k = 11)

# %%
result[1][0][1:11]
# Out:
# array([140731, 119476,  36578, 158616, 106290, 202947, 100519,  75841,
#        188267, 137321])

# %%
df.iloc[result[1][0][1:11]]
# Out:
#               artist_name                track_id  \
# 140731             NIVIRO  7p1oMCfqslKQycoCY3Nup6
# 119476         Red Velvet  7klUw55UuyxUyGZVsj3Hod
# 36578             Thoreau  2v4Lw15R9v3z563E5W1T4I
# 158616            Thoreau  2v4Lw15R9v3z563E5W1T4I
# 106290  NateWantsToBattle  157ekTVX237WBUvJNCEElf
# 202947  NateWantsToBattle  157ekTVX237WBUvJNCEElf
# 100519     Tanishk Bagchi  3LTIYvh7hd4S1AsQkjX26d
# 75841           이창섭(BTOB)  08yvBpqYTvwRYwLceE92Nj
# 188267          이창섭(BTOB)  08yvBpqYTvwRYwLceE92Nj
# 137321            Popcaan  5VLkFNnadOJxXkzoBQbL7H
#
#                            track_name  acousticness  danceability  \
# 140731                         Flares       0.04230         0.518
# 119476                          Taste       0.08780         0.466
# 36578   Like We Used To (feat. Jeris)       0.02420         0.247
# 158616  Like We Used To (feat. Jeris)       0.02420         0.247
# 106290                        Phantom       0.00154         0.320
# 202947                        Phantom       0.00154         0.320
# 100519  Sawarne Lage - Female Version       0.15000         0.613
# 75841                         Falling       0.21500         0.568
# 188267                        Falling       0.21500         0.568
# 137321                   Bullet Proof       0.32500         0.531
#
#         duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 140731       205500   0.791          0.000220    1    0.1420    -5.190     1
# 119476       184776   0.723          0.000000    1    0.0737    -5.323     1
# 36578        209920   0.760          0.000000    1    0.0719    -4.764     1
# 158616       209920   0.760          0.000000    1    0.0719    -4.764     1
# 106290       254400   0.931          0.000000    1    0.4040    -5.323     1
# 202947       254400   0.931          0.000000    1    0.4040    -5.323     1
# 100519       167007   0.693          0.000072    1    0.0935    -5.565     1
# 75841        213458   0.546          0.000000    2    0.0538    -4.872     1
# 188267       213458   0.546          0.000000    2    0.0538    -4.872     1
# 137321       180062   0.710          0.000000    0    0.0605    -4.790     1
#
#         speechiness    tempo  time_signature  valence  popularity
# 140731       0.1920  199.906               4    0.316          44
# 119476       0.3990  199.656               4    0.884          48
# 36578        0.0944  199.977               4    0.164          21
# 158616       0.0944  199.977               4    0.164          19
# 106290       0.1560  200.073               4    0.484          50
# 202947       0.1560  200.073               4    0.484          47
# 100519       0.0675  200.145               4    0.270          25
# 75841        0.0505  199.974               4    0.585           7
# 188267       0.0505  199.974               4    0.585          28
# 137321       0.4180  200.300               4    0.772          47

# %%
pickle.dump(model, open('rm_03.pkl', 'wb'))
