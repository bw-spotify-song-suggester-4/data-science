# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from scipy.spatial import KDTree
import spotipy
import pickle

# %%
# df = pd.read_csv('./data/SpotifyAudioFeaturesApril2019.csv')
df = pd.read_csv('./data/merged_data.csv')

# %%
scaler = MinMaxScaler()

# %%
df.head()
# Out:
#   artist_name                track_id  \
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1          YG  1tHDG53xJNGsItRA3vfVgs
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
#
#                                        track_name  acousticness  danceability  \
# 0  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820         0.743
# 1                    BAND DRUM (feat. A$AP Rocky)      0.024400         0.846
# 2                                   Radio Silence      0.025000         0.603
# 3                                         Lactose      0.029400         0.800
# 4                             Same - Original mix      0.000035         0.783
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       238373   0.339             0.000    1    0.0812    -7.678     1
# 1       214800   0.557             0.000    8    0.2860    -7.259     1
# ...

# %%
df['track_id'][2]
# Out:
# '6Wosx2euFPMT14UXiWudMy'

# %%
# X = df.drop(['artist_name', 'track_id', 'track_name', 'duration_ms', 'popularity'], axis = 1)
# scaler.fit_transform(X)

# %%
model = KDTree(df.drop(['artist_name', 'track_id', 'track_name', 'duration_ms', 'popularity'], axis = 1))

# %%
result = model.query(df[df['track_id'] == '6Wosx2euFPMT14UXiWudMy'].drop(['artist_name', 'track_id', 'track_name', 'duration_ms', 'popularity'], axis = 1), k = 11)

# %%
df[df['track_id'] == '2v4Lw15R9v3z563E5W1T4I']
# Out:
#       artist_name                track_id                     track_name  \
# 36566     Thoreau  2v4Lw15R9v3z563E5W1T4I  Like We Used To (feat. Jeris)
#
#        acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 36566        0.0242         0.247       209920    0.76               0.0    1
#
#        liveness  loudness  mode  speechiness    tempo  time_signature  \
# 36566    0.0719    -4.764     1       0.0944  199.977               4
#
#        valence  popularity
# 36566    0.164          21

# %%
result[1][0][1:11]
# Out:
# array([ 78421,  15188,  38307,  68429, 124556,  35158,  22539,   5411,
#         73798,  82195])

# %%
result = model.query([[.01, .5, .5, .1, 1, .1, -5, 1, .5, 190, 4, .5]], k = 11)

# %%
result[1][0][1:11]
# Out:
# array([ 98577,  37929,  89612,  70548,  83886, 110115,   7902,  34153,
#        124521, 111037])

# %%
df.iloc[result[1][0][1:11]]
# Out:
#                 artist_name                track_id  \
# 98577               Farruko  2VRVV7cvAGPJ2EBU4FIVCz
# 37929        Kendrick Lamar  3m7B5vvKuFJ3gMARIzyKef
# 89612               ShitKid  20OPqfLQ8U11ZdbxznG860
# 70548   Kurt Hugo Schneider  0TO7NEjVQJtmPEyIVExFOo
# 83886             GFMBRYYCE  3LILX3Peeirfb3NR5kfiyB
# 110115              Wallows  6qMiZK4mGuCRkVwRFds4Sm
# 7902                 Outlaw  22X23ozlTPi2j36tSG5LxS
# 34153     The Lawrence Arms  3X6FAxvQlvnsHYbRTlxUnj
# 124521              N.E.R.D  739vCwA3EpBSkk3uDsI2wB
# 111037              Allie X  4P4nrjgbpghZ9oG3TaMV5n
#
#                           track_name  acousticness  danceability  duration_ms  \
# 98577                          Nadie      0.190000         0.679       228760
# 37929                       ELEMENT.      0.223000         0.759       208733
# 89612                Oh Me I'm Never      0.013500         0.498       177884
# ...

# %%
pickle.dump(model, open('rm_04.pkl', 'wb'))
