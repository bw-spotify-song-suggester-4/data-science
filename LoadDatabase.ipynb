# %%
from flask import Flask
from flask_sqlalchemy import SQLAlchemy
import io
import json
import numpy as np
from os import getenv
import pandas as pd
import pickle
from sklearn.neighbors import KDTree

# %%
loaded_model = pickle.load(open('./rm_04.pkl', 'rb'))

# %%
df = pd.read_csv('./data/merged_data.csv')

# %%
df.head()
# Out:
#   artist_name                track_id  \
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1          YG  1tHDG53xJNGsItRA3vfVgs
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
#
#                                        track_name  acousticness  danceability  \
# 0  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820         0.743
# 1                    BAND DRUM (feat. A$AP Rocky)      0.024400         0.846
# 2                                   Radio Silence      0.025000         0.603
# 3                                         Lactose      0.029400         0.800
# 4                             Same - Original mix      0.000035         0.783
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       238373   0.339             0.000    1    0.0812    -7.678     1
# 1       214800   0.557             0.000    8    0.2860    -7.259     1
# 2       138913   0.723             0.000    9    0.0824    -5.890     0
# 3       125381   0.579             0.912    5    0.0994   -12.118     0
# 4       124016   0.792             0.878    7    0.0332   -10.277     1
#
#    speechiness    tempo  time_signature  valence  popularity
# 0       0.4090  203.927               4    0.118          15
# 1       0.4570  159.009               4    0.371           0
# 2       0.0454  114.966               4    0.382          56
# 3       0.0701  123.003               4    0.641           0
# 4       0.0661  120.047               4    0.928           0

# %%
features = df.columns.tolist()

# %%
remove_list = ['artist_name', 'track_id', 'track_name', 'duration_ms', 'popularity']

# %%
for feature in remove_list:
    features.remove(feature)

# %%
features
# Out:
# ['acousticness',
#  'danceability',
#  'energy',
#  'instrumentalness',
#  'key',
#  'liveness',
#  'loudness',
#  'mode',
#  'speechiness',
#  'tempo',
#  'time_signature',
#  'valence']

# %%
_, ind = loaded_model.query(np.array(df[features].loc[0]).reshape(1, -1), k=15)

# %%
df.loc[ind[0]][['artist_name', 'track_id', 'track_name']]
# Out:
#                    artist_name                track_id  \
# 0                           YG  2RM4jf1Xa9zPgMGRDiht8O
# 123705                      YG  0ZNrc4kNeQYD9koZ3KvCsy
# 84012                    Ylvis  4MxR2PXg5Q4O2LyHKcA8CV
# 53267          Renacimiento 74  4jxxGcGGeizXIMPUwktBXj
# 81193                  Kevo DJ  3M7s1z1wS2EMMD2w5pFi1n
# 84608           Mark Wilkinson  3C2kX2xlxjidJugdAkE0xk
# 17750         Cumbias Viejitas  54NT7rrr2IrZvjJdZz7P3C
# 59548          CantoParaBailar  1gIygRPVK3wb3LzxloV1xJ
# 14094                     Ripe  4AvFWfjlu5qcQxmhKn95rk
# 13825          Danielle Nicole  7riVWDCXzmFlOjhFzkr3ed
# 59300      Laura Jean Anderson  0iyh42xE36aH1IRpDqdRhb
# 89993                Chuy Vega  6bPSOLci97hXKUsJBuImhE
# 31722                  Oso Oso  29WtKJi02mn2a214Aw0gcC
# 108147  Los Tucanes De Tijuana  1Gm40qHAlhhAEnVq9zhQnN
# 21358                Beth Hart  4xZkawiWBbDr8E2q8ohoNu
#
#                                               track_name
# 0         Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj
# 123705  BIG BANK (feat. 2 Chainz, Big Sean, Nicki Minaj)
# 84012                                      Who Can It Be
# 53267                                 El Flaco Quebrador
# 81193                                       Salio el Sol
# 84608                                   Another Necklace
# 17750               Vivo Pensando En Ti - Versión Cumbia
# 59548                                     Chica del Este
# 14094                                Yesterday's Clothes
# 13825                                        Cry No More
# 59300                          Silence Won't Help Me Now
# 89993                                   Tarde o Temprano
# 31722                                          the slope
# 108147                                      Parrandeando
# 21358                        Sitting On Top Of The World

# %%
df.shape
# Out:
# (130989, 17)

# %%
_, ind = loaded_model.query(np.array(df[features].loc[1]).reshape(1, -1), k=15)

# %%
df.loc[ind[0]][['artist_name', 'track_id', 'track_name']]
# Out:
#              artist_name                track_id  \
# 1                     YG  1tHDG53xJNGsItRA3vfVgs
# 97166           NovaCain  1Abf6m9pfBpRDPOtMRsMdj
# 124813                YG  50wkDxcIfamIajKwmgp0iB
# 45902          Lil Brain  1Z9R5bOGeLBq15x8PxtyAF
# 63828    J.K. The Reaper  2FAovUU65GRy6A9UPWyCzC
# 48302          SKB Solow  4RFXgqqfbYFpzgawXaZxEn
# 124239       Bhad Bhabie  3hv6ndi7uFT9L9wrhQCsqY
# 4722                SoMo  7uo4ZxiZhhyDDQilKyjDWR
# 124060           Ronny J  6JxdRch1BQkPVUWjcuudvI
# 24218      Paul Williams  4qYPVOUE8Lj1cVyIhtJmf9
# 92700       BlueHunnidss  6paaedbuG6P95eun74mnHu
# 22988           Mykfresh  6HCFrFSGnHna7VXhLAJKMW
# 90776      Lloyd P-White  2VTUtj9dP17MlEPo08PhoE
# 26366     Raleigh Keegan  2at0wGOtwh1nmmHDW8u0g8
# 67824   Arsonal da Rebel  7yS8yJPKp7U5sGDkpUH41P
#
#                                        track_name
# 1                    BAND DRUM (feat. A$AP Rocky)
# 97166                 That Booty (For That Booty)
# 124813                 HANDGUN (feat. A$AP Rocky)
# 45902                                        Xoom
# 63828                                    City Boy
# 48302                            Want to Get Rich
# 124239        Gucci Flip Flops (feat. Lil Yachty)
# 4722                                 Wake Up Call
# 124060  Costa Rica (feat. Ski Mask The Slump God)
# 24218                                 Crush Crush
# 92700                         Looking for a Freak
# 22988                             Been on My Shit
# 90776                                       Dream
# 26366                     Quit Lookin' for a Sign
# 67824                                  Real Nigga

# %%
pg_user = getenv('POSTGRES_USER')
pg_pass = getenv('POSTGRES_PASSWORD')
pg_url = getenv('POSTGRES_URL')
pg_db = getenv('POSTGRES_DB')
DATABASE_URL = f'postgresql+psycopg2://{pg_user}:{pg_pass}@{pg_url}/{pg_db}'

# %%
app = Flask(__name__)
app.config['SQLALCHEMY_DATABASE_URI'] = DATABASE_URL
app.config['SQLALCHEMY_TRACK_MODIFICATIONS'] = False
DB = SQLAlchemy(app)

# %%
df['id'] = df.index

# %%
df.head(0).to_sql('track', con=DB.engine, if_exists='replace', index=False)
conn = DB.engine.raw_connection()
curs = conn.cursor()
output = io.StringIO()
df.to_csv(output, sep='\t', header=False, index=False)
output.seek(0)
curs.copy_from(output, 'track', null="")
conn.commit()
conn.close()

# %%
DB.Model.metadata.reflect(DB.engine)

# %%
features
# Out:
# ['acousticness',
#  'danceability',
#  'energy',
#  'instrumentalness',
#  'key',
#  'liveness',
#  'loudness',
#  'mode',
#  'speechiness',
#  'tempo',
#  'time_signature',
#  'valence']

# %%
class Track(DB.Model):
    __table__ = DB.Model.metadata.tables['track']
    
    def to_array(self):
        return np.array([self.acousticness, 
                         self.danceability,
                         self.energy,
                         self.instrumentalness, 
                         self.key, 
                         self.liveness, 
                         self.loudness, 
                         self.mode, 
                         self.speechiness, 
                         self.tempo, 
                         self.time_signature, 
                         self.valence])

    def print_dict(self):
        return {
            'track_id': self.track_id,
            'track_name': self.track_name,
            'artist_name': self.artist_name,
            'acousticness': self.acousticness,
            'danceability': self.danceability,
            'duration_ms': self.duration_ms,
            'energy': self.energy,
            'instrumentalness': self.instrumentalness,
            'key': self.key,
            'liveness': self.liveness,
            'loudness': self.loudness,
            'mode': self.mode,
            'speechiness': self.speechiness,
            'tempo': self.tempo,
            'time_signature': self.time_signature,
            'valence': self.valence,
            'popularity': self.popularity
        }

    def __repr__(self):
        return json.dumps(self.print_dict())

# %%
query1 = Track.query.filter(Track.id == 0).first()

# %%
print(query1.to_array().shape)
# Out:
# (12,)

# %%
_, ind = loaded_model.query(query1.to_array().reshape(1, -1), k=15)

# %%
indices = [val.item() for val in ind[0]]

# %%
query2 = Track.query.filter(Track.id.in_(indices)).all()

# %%
for result in query2:
    print(result, '\n')
# Out:
# {"track_id": "2RM4jf1Xa9zPgMGRDiht8O", "track_name": "Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj", "artist_name": "YG", "acousticness": 0.00582, "danceability": 0.743, "duration_ms": 238373, "energy": 0.339, "instrumentalness": 0.0, "key": 1, "liveness": 0.0812, "loudness": -7.678, "mode": 1, "speechiness": 0.409, "tempo": 203.927, "time_signature": 4, "valence": 0.118, "popularity": 15}
#
# {"track_id": "7riVWDCXzmFlOjhFzkr3ed", "track_name": "Cry No More", "artist_name": "Danielle Nicole", "acousticness": 0.185, "danceability": 0.53, "duration_ms": 262467, "energy": 0.617, "instrumentalness": 0.00148, "key": 1, "liveness": 0.107, "loudness": -6.356, "mode": 1, "speechiness": 0.0377, "tempo": 203.794, "time_signature": 4, "valence": 0.669, "popularity": 38}
#
# {"track_id": "4AvFWfjlu5qcQxmhKn95rk", "track_name": "Yesterday's Clothes", "artist_name": "Ripe", "acousticness": 0.127, "danceability": 0.596, "duration_ms": 261740, "energy": 0.622, "instrumentalness": 7.44e-05, "key": 0, "liveness": 0.0823, "loudness": -6.991, "mode": 1, "speechiness": 0.0801, "tempo": 204.032, "time_signature": 4, "valence": 0.775, "popularity": 39}
#
# {"track_id": "54NT7rrr2IrZvjJdZz7P3C", "track_name": "Vivo Pensando En Ti - Versi\u00f3n Cumbia", "artist_name": "Cumbias Viejitas", "acousticness": 0.168, "danceability": 0.424, "duration_ms": 204826, "energy": 0.867, "instrumentalness": 2.78e-06, "key": 0, "liveness": 0.0823, "loudness": -7.677, "mode": 1, "speechiness": 0.116, "tempo": 203.581, "time_signature": 4, "valence": 0.698, "popularity": 0}
#
# {"track_id": "4xZkawiWBbDr8E2q8ohoNu", "track_name": "Sitting On Top Of The World", "artist_name": "Beth Hart", "acousticness": 0.0447, "danceability": 0.312, "duration_ms": 238737, "energy": 0.812, "instrumentalness": 0.00305, "key": 2, "liveness": 0.0818, "loudness": -6.381, "mode": 1, "speechiness": 0.0382, "tempo": 204.019, "time_signature": 3, "valence": 0.774, "popularity": 35}
#
# {"track_id": "29WtKJi02mn2a214Aw0gcC", "track_name": "the slope", "artist_name": "Oso Oso", "acousticness": 0.000149, "danceability": 0.439, "duration_ms": 156378, "energy": 0.902, "instrumentalness": 0.04, "key": 2, "liveness": 0.282, "loudness": -6.296, "mode": 1, "speechiness": 0.0404, "tempo": 204.017, "time_signature": 4, "valence": 0.5, "popularity": 30}
#
# {"track_id": "4jxxGcGGeizXIMPUwktBXj", "track_name": "El Flaco Quebrador", "artist_name": "Renacimiento 74", "acousticness": 0.0417, "danceability": 0.529, "duration_ms": 154305, "energy": 0.594, "instrumentalness": 0.0, "key": 1, "liveness": 0.0419, "loudness": -7.156, "mode": 1, "speechiness": 0.122, "tempo": 204.427, "time_signature": 4, "valence": 0.936, "popularity": 24}
#
# {"track_id": "0iyh42xE36aH1IRpDqdRhb", "track_name": "Silence Won't Help Me Now", "artist_name": "Laura Jean Anderson", "acousticness": 0.154, "danceability": 0.411, "duration_ms": 240715, "energy": 0.564, "instrumentalness": 6.12e-05, "key": 0, "liveness": 0.283, "loudness": -8.671, "mode": 1, "speechiness": 0.0458, "tempo": 203.721, "time_signature": 4, "valence": 0.263, "popularity": 13}
#
# {"track_id": "1gIygRPVK3wb3LzxloV1xJ", "track_name": "Chica del Este", "artist_name": "CantoParaBailar", "acousticness": 0.0912, "danceability": 0.52, "duration_ms": 204197, "energy": 0.815, "instrumentalness": 0.0166, "key": 0, "liveness": 0.183, "loudness": -7.825, "mode": 1, "speechiness": 0.187, "tempo": 203.99, "time_signature": 4, "valence": 0.955, "popularity": 31}
#
# {"track_id": "3M7s1z1wS2EMMD2w5pFi1n", "track_name": "Salio el Sol", "artist_name": "Kevo DJ", "acousticness": 0.216, "danceability": 0.728, "duration_ms": 185882, "energy": 0.53, "instrumentalness": 8.49e-06, "key": 0, "liveness": 0.0681, "loudness": -7.339, "mode": 1, "speechiness": 0.3, "tempo": 204.033, "time_signature": 4, "valence": 0.622, "popularity": 0}
#
# {"track_id": "4MxR2PXg5Q4O2LyHKcA8CV", "track_name": "Who Can It Be", "artist_name": "Ylvis", "acousticness": 0.125, "danceability": 0.48, "duration_ms": 110075, "energy": 0.56, "instrumentalness": 0.0, "key": 1, "liveness": 0.136, "loudness": -7.868, "mode": 1, "speechiness": 0.351, "tempo": 204.162, "time_signature": 4, "valence": 0.571, "popularity": 37}
#
# {"track_id": "3C2kX2xlxjidJugdAkE0xk", "track_name": "Another Necklace", "artist_name": "Mark Wilkinson", "acousticness": 0.509, "danceability": 0.285, "duration_ms": 241253, "energy": 0.352, "instrumentalness": 3.41e-06, "key": 0, "liveness": 0.113, "loudness": -7.892, "mode": 1, "speechiness": 0.0304, "tempo": 203.509, "time_signature": 4, "valence": 0.128, "popularity": 29}
#
# {"track_id": "6bPSOLci97hXKUsJBuImhE", "track_name": "Tarde o Temprano", "artist_name": "Chuy Vega", "acousticness": 0.0379, "danceability": 0.441, "duration_ms": 225202, "energy": 0.586, "instrumentalness": 7.7e-06, "key": 1, "liveness": 0.0615, "loudness": -7.25, "mode": 1, "speechiness": 0.033, "tempo": 202.347, "time_signature": 4, "valence": 0.794, "popularity": 3}
#
# {"track_id": "1Gm40qHAlhhAEnVq9zhQnN", "track_name": "Parrandeando", "artist_name": "Los Tucanes De Tijuana", "acousticness": 0.0135, "danceability": 0.578, "duration_ms": 221880, "energy": 0.706, "instrumentalness": 0.0, "key": 0, "liveness": 0.0866, "loudness": -7.653, "mode": 1, "speechiness": 0.079, "tempo": 202.727, "time_signature": 3, "valence": 0.817, "popularity": 49}
#
# {"track_id": "0ZNrc4kNeQYD9koZ3KvCsy", "track_name": "BIG BANK (feat. 2 Chainz, Big Sean, Nicki Minaj)", "artist_name": "YG", "acousticness": 0.00552, "danceability": 0.745, "duration_ms": 237240, "energy": 0.346, "instrumentalness": 0.0, "key": 1, "liveness": 0.0881, "loudness": -7.709, "mode": 1, "speechiness": 0.331, "tempo": 203.911, "time_signature": 4, "valence": 0.112, "popularity": 82}
