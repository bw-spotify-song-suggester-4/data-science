# %%
import pickle

# %%
model = pickle.load(open('rm_05.pkl','rb'))

# %%
scaler = pickle.load(open('sc_05.pkl','rb'))

# %%
result = model.query(scaler.transform([[.01, .5, .5, .1, 1, .1, -5, 1, .5, 190, 4, .5]]), k = 11)

# %%
import pandas as pd
df = pd.read_csv('./data/merged_data.csv')

# %%
results = df.iloc[result[1][0][0:11]].copy()

# %%
results['distance'] = list(result[0][0][0:11])
results
# Out:
#             artist_name                track_id                  track_name  \
# 49943     Big Tray Deee  1rjXll4mBCTbnAtOLUf5SI            California C-Mix
# 81328        Shoddy Boi  6L5Z6SQrblQtBxaYYHWEhp     Trappin from a Distance
# 15738        Steve Void  4r0Wiso07ifBHiy87i8Ja3  Comfortable [Watson Remix]
# 84012             Ylvis  4MxR2PXg5Q4O2LyHKcA8CV               Who Can It Be
# 81438   Johnny 2 Phones  73nldey8J0M4Z1zblE6ZF0                    Code Red
# 23793            John J  6YTU7SdeWMEgGeQ5vaByZr             Talking Bottles
# 70111             Bamon  0rlYWu1NElxjsB4jrIt5hA                    Day Ones
# 70960  Carlton Carvalho  3B1wNOKJcRPNSZwqp8JkFj                 Still Do It
# 85866             Luniz  5aL4iuo2XgMA4d2CyWRYUv              Keep It Moving
# 24230     Secret Circle  2MwIkkJujEmXa7o9Nc6HeI                 Ounce of It
# 87613            1 Time  0VsnbSr0rGLLAV9TBP3dd6              It's Not a Job
#
#        acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 49943      0.017400         0.519       331572   0.455           0.00000    1
# 81328      0.031200         0.590       173467   0.560           0.00000    2
# 15738      0.053100         0.398       186711   0.531           0.00014    1
# 84012      0.125000         0.480       110075   0.560           0.00000    1
# 81438      0.020200         0.509       147122   0.662           0.02130    2
# 23793      0.160000         0.611       176744   0.572           0.00000    1
# 70111      0.009160         0.545       242600   0.557           0.00000    1
# 70960      0.017500         0.500       239203   0.550           0.00000    0
# 85866      0.000953         0.573       181395   0.436           0.00000    1
# 24230      0.018400         0.638       247978   0.542           0.00000    1
# 87613      0.178000         0.624       217173   0.608           0.02510    2
#
#        liveness  loudness  mode  speechiness    tempo  time_signature  \
# 49943    0.0993   -10.254     1        0.424  184.477               4
# 81328    0.1060   -10.902     1        0.489  165.947               4
# 15738    0.0818    -6.653     1        0.347  180.003               4
# 84012    0.1360    -7.868     1        0.351  204.162               4
# 81438    0.0679    -6.002     1        0.431  205.807               4
# 23793    0.0942    -8.386     1        0.483  172.201               4
# 70111    0.0672    -9.333     1        0.367  150.706               4
# 70960    0.0631    -7.525     1        0.457  139.506               4
# 85866    0.1870   -13.940     1        0.376  172.071               4
# 24230    0.0847    -9.344     1        0.476  178.007               4
# 87613    0.1330    -6.084     1        0.458  174.157               4
#
#        valence  popularity  distance
# 49943    0.531          17  0.165257
# 81328    0.422          10  0.234754
# 15738    0.408          14  0.243905
# 84012    0.571          37  0.250656
# 81438    0.616          12  0.254441
# 23793    0.416           0  0.256428
# 70111    0.459          15  0.258125
# 70960    0.522          26  0.259075
# 85866    0.449          21  0.268848
# 24230    0.310           0  0.274273
# 87613    0.441          17  0.283330

# %%
result = model.query(scaler.transform(df[df['track_id'] == '4V79NKNUFkjzHWcPLtdlNM'].drop(['artist_name', 'track_id', 'track_name', 'duration_ms', 'popularity'], axis = 1)), k = 11)

# %%
results = df.iloc[result[1][0][0:11]].copy()

# %%
results['distance'] = list(result[0][0][0:11])
results
# Out:
#                     artist_name                track_id  \
# 5339                 Mazzy Star  4V79NKNUFkjzHWcPLtdlNM
# 103175  Wolfgang Amadeus Mozart  27hYrLMy8FgUN3ALJuAHY3
# 117033           Claude Debussy  7GankMKTqn3wKqwIKfzPno
# 3085      Johann Sebastian Bach  3S3CdN2i6QV2pdxFgWlH4j
# 102995        Bruce Springsteen  5RGoHsnlh2nWtushRYqvxd
# 14320          Imaginary Future  4IiqPO0Cj9kzEJcmdE30vW
# 1342      Johann Sebastian Bach  3IvmEuA9yB363C9rfosFB2
# 71527      Ludwig van Beethoven  5RL3QBJ5JZwqScbxcORUcT
# 118739                  Wun Two  1o6WHsUBfQosDXtP2NpEtd
# 110516    Johann Sebastian Bach  5ZsUiqHRubSalLf2QdK0bs
# 118773            NEEDTOBREATHE  6jgctvg29agevJf8q0eXv8
#
#                                                track_name  acousticness  \
# 5339                             Quiet, The Winter Harbor         0.973
# 103175  String Quartet No. 15 in D Minor, K. 421/417b:...         0.970
# 117033  Impressions de Pelléas, d'après Pelléas et Mél...         0.988
# 3085    Ich will den Kreuzstab gerne tragen, BWV 56: I...         0.942
# 102995  The Promise - Live at the Palace Theatre, Alba...         0.923
# 14320                                   I Won't Back Down         0.962
# 1342    Violin Sonata No. 6 in G Major, BWV 1019a: I. ...         0.924
# 71527   Symphony No. 1 in C Major, Op. 21: II. Andante...         0.962
# 118739                               breaking the silence         0.913
# 110516              Christus, der ist mein Leben, BWV 281         0.988
# 118773                                            Darling         0.956
#
#         danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 5339           0.321       255358  0.0792          0.104000    5    0.0888
# 103175         0.355       346653  0.0265          0.114000    5    0.1360
# 117033         0.418       902520  0.0775          0.000340    5    0.1140
# 3085           0.276        96373  0.1990          0.000026    6    0.0987
# 102995         0.312       363853  0.0865          0.000002    5    0.2350
# 14320          0.364       144419  0.0544          0.000000    5    0.1030
# 1342           0.282       502559  0.1260          0.000270    6    0.1920
# 71527          0.351       327908  0.0150          0.057000    5    0.0792
# 118739         0.215        28235  0.0365          0.175000    6    0.1100
# 110516         0.256        28320  0.1340          0.000004    5    0.1210
# 118773         0.393       313408  0.1740          0.000005    6    0.1120
#
#         loudness  mode  speechiness    tempo  time_signature  valence  \
# 5339     -17.737     1       0.0329  145.293               3   0.1060
# 103175   -20.781     1       0.0474  127.936               3   0.1050
# 117033   -23.904     1       0.0712  131.940               3   0.0438
# 3085     -14.986     1       0.0348  134.608               3   0.0781
# 102995   -17.499     1       0.0347  165.232               3   0.1320
# 14320    -15.755     1       0.0466  171.650               3   0.2340
# 1342     -17.689     1       0.0440  129.432               3   0.1650
# 71527    -25.711     1       0.0427  110.979               3   0.0833
# 118739   -24.087     1       0.0377  137.434               3   0.0439
# 110516   -21.752     1       0.0525  119.639               3   0.2300
# 118773   -10.085     1       0.0388  142.310               3   0.1260
#
#         popularity  distance
# 5339            34  0.000000
# 103175          28  0.117290
# 117033           5  0.198359
# 3085             1  0.202795
# 102995          34  0.204803
# 14320           38  0.205789
# 1342             3  0.208516
# 71527            7  0.208704
# 118739           0  0.214382
# 110516           0  0.223343
# 118773          49  0.223675

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
results[['danceability', 'energy', 'valence']].plot.bar()
plt.show()

# %%
results[['danceability', 'valence']].plot.box()
plt.show()

# %%
results.plot.scatter(x = 'danceability', y = 'energy', c = 'valence', cmap = 'coolwarm')
plt.show()

# %%
grid = sns.PairGrid(results)
grid.map_diag(sns.distplot)
grid.map_upper(plt.scatter)
grid.map_lower(sns.kdeplot)
# Out:
# C:\Users\John\Anaconda3\envs\DS-U4-BW\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-15-9bad920bb0ef> in <module>
#       2 grid.map_diag(sns.distplot)
#       3 grid.map_upper(plt.scatter)
# ----> 4 grid.map_lower(sns.kdeplot)
#
# ~\Anaconda3\envs\DS-U4-BW\lib\site-packages\seaborn\axisgrid.py in map_lower(self, func, **kwargs)
#    1378         """
#    1379         indices = zip(*np.tril_indices_from(self.axes, -1))
# -> 1380         self._map_bivariate(func, indices, **kwargs)
#    1381         return self
#    1382
#
# ~\Anaconda3\envs\DS-U4-BW\lib\site-packages\seaborn\axisgrid.py in _map_bivariate(self, func, indices, **kwargs)
#    1504             y_var = self.y_vars[i]
#    1505             ax = self.axes[i, j]
# -> 1506             self._plot_bivariate(x_var, y_var, ax, func, kw_color, **kws)
#    1507         self._add_axis_labels()
#    1508
#
# ~\Anaconda3\envs\DS-U4-BW\lib\site-packages\seaborn\axisgrid.py in _plot_bivariate(self, x_var, y_var, ax, func, kw_color, **kwargs)
#    1534             color = self.palette[k] if kw_color is None else kw_color
#    1535
# -> 1536             func(x, y, label=label_k, color=color, **kwargs)
#    1537
#    1538         self._clean_axis(ax)
#
# ~\Anaconda3\envs\DS-U4-BW\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     699         ax = _bivariate_kdeplot(x, y, shade, shade_lowest,
#     700                                 kernel, bw, gridsize, cut, clip, legend,
# --> 701                                 cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     702     else:
#     703         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#
# ~\Anaconda3\envs\DS-U4-BW\lib\site-packages\seaborn\distributions.py in _bivariate_kdeplot(x, y, filled, fill_lowest, kernel, bw, gridsize, cut, clip, axlabel, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     405         xx, yy, z = _statsmodels_bivariate_kde(x, y, bw, gridsize, cut, clip)
#     406     else:
# --> 407         xx, yy, z = _scipy_bivariate_kde(x, y, bw, gridsize, cut, clip)
#     408
#     409     # Plot the contours
#
# ~\Anaconda3\envs\DS-U4-BW\lib\site-packages\seaborn\distributions.py in _scipy_bivariate_kde(x, y, bw, gridsize, cut, clip)
#     486     """Compute a bivariate kde using scipy."""
#     487     data = np.c_[x, y]
# --> 488     kde = stats.gaussian_kde(data.T, bw_method=bw)
#     489     data_std = data.std(axis=0, ddof=1)
#     490     if isinstance(bw, str):
#
# ~\Anaconda3\envs\DS-U4-BW\lib\site-packages\scipy\stats\kde.py in __init__(self, dataset, bw_method, weights)
#     206             self._neff = 1/sum(self._weights**2)
#     207
# --> 208         self.set_bandwidth(bw_method=bw_method)
#     209
#     210     def evaluate(self, points):
#
# ~\Anaconda3\envs\DS-U4-BW\lib\site-packages\scipy\stats\kde.py in set_bandwidth(self, bw_method)
#     552             raise ValueError(msg)
#     553
# --> 554         self._compute_covariance()
#     555
#     556     def _compute_covariance(self):
#
# ~\Anaconda3\envs\DS-U4-BW\lib\site-packages\scipy\stats\kde.py in _compute_covariance(self)
#     564                                                bias=False,
#     565                                                aweights=self.weights))
# --> 566             self._data_inv_cov = linalg.inv(self._data_covariance)
#     567
#     568         self.covariance = self._data_covariance * self.factor**2
#
# ~\Anaconda3\envs\DS-U4-BW\lib\site-packages\scipy\linalg\basic.py in inv(a, overwrite_a, check_finite)
#     972         inv_a, info = getri(lu, piv, lwork=lwork, overwrite_lu=1)
#     973     if info > 0:
# --> 974         raise LinAlgError("singular matrix")
#     975     if info < 0:
#     976         raise ValueError('illegal value in %d-th argument of internal '
#
# LinAlgError: singular matrix
